# %% [markdown]
# <a href="https://colab.research.google.com/github/Ray7788/FT5005-Group6/blob/main/Cleaned%20Data/classicML_revenue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab\ Notebooks/FT5005/Cleaned\ Data/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/FT5005/Cleaned Data

# %%
import pandas as pd
import numpy as np
import os
import sys
import argparse
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
processed_df = pd.read_csv("EBITDA_new.csv")
processed_df.head(3)


# Set up prediction target, either EBITDA or revenue_
# target = 'EBITDA'
target = 'revenue_' # must include "_"

# %% [markdown]
# # Implement LightGBM

# %%
from sklearn.metrics import mean_squared_error, r2_score
import lightgbm as lgb

# Select features and target variable
# features exclude:
features = [col for col in processed_df.columns if col not in [ target, 'fiscalQuarter']
]

# Remove missing values
processed_df = processed_df.dropna(subset=features + [target])

# Split the dataset based on year

train_df = processed_df[processed_df['year'] <= 2020]
test_df = processed_df[processed_df['year'] > 2020]

# Update train and test sets
X_train = train_df[features]
y_train = train_df[target]
X_test = test_df[features]
y_test = test_df[target]
# Create LightGBM datasets
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# Define parameters
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'boosting_type': 'gbdt',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'max_depth': -1,
    'verbose': -1
}

# Train the model
lgb_model = lgb.train(params, train_data, valid_sets=[train_data, test_data], num_boost_round=100)

# Make predictions
y_pred = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)

# Evaluate the model
rmse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse}")
print(f"R2 Score: {r2}")
# Out:
# RMSE: 287.79492995958833
# R2 Score: 0.9989434129086335

# %% [markdown]
# # Implement XGBoost

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score


xgb_model = XGBRegressor(
    objective='reg:squarederror',
    learning_rate=0.1,
    max_depth=6,
    n_estimators=1000,
    early_stopping_rounds=50,
    verbosity=1
)

xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_test, y_test)],

)

# prediction
y_pred_xgb = xgb_model.predict(X_test)

# evaluation
rmse_xgb = mean_squared_error(y_test, y_pred_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

print(f"XGBoost RMSE: {rmse_xgb}")
print(f"XGBoost R2 Score: {r2_xgb}")
# Out:
# [0]	validation_0-rmse:522.05614	validation_1-rmse:474.02140
# [1]	validation_0-rmse:471.01964	validation_1-rmse:430.40689
# [2]	validation_0-rmse:424.99492	validation_1-rmse:390.73989
# [3]	validation_0-rmse:383.50622	validation_1-rmse:355.23979
# [4]	validation_0-rmse:346.08141	validation_1-rmse:322.76102
# [5]	validation_0-rmse:312.33144	validation_1-rmse:293.44804
# [6]	validation_0-rmse:281.88070	validation_1-rmse:264.08752
# [7]	validation_0-rmse:254.39569	validation_1-rmse:240.19523
# [8]	validation_0-rmse:229.59904	validation_1-rmse:218.21323
# [9]	validation_0-rmse:207.24266	validation_1-rmse:198.66691
# [10]	validation_0-rmse:187.08700	validation_1-rmse:179.26692
# [11]	validation_0-rmse:168.84879	validation_1-rmse:163.50485
# [12]	validation_0-rmse:152.44854	validation_1-rmse:147.73559
# [13]	validation_0-rmse:137.62035	validation_1-rmse:134.83424
# [14]	validation_0-rmse:124.22315	validation_1-rmse:123.02745
# [15]	validation_0-rmse:112.13065	validation_1-rmse:112.47276
# [16]	validation_0-rmse:101.24018	validation_1-rmse:102.82805
# [17]	validation_0-rmse:91.39842	validation_1-rmse:94.10886
# [18]	validation_0-rmse:82.51870	validation_1-rmse:86.32406
# [19]	validation_0-rmse:74.49339	validation_1-rmse:79.33296
# [20]	validation_0-rmse:67.25476	validation_1-rmse:73.00138
# [21]	validation_0-rmse:60.71512	validation_1-rmse:67.49370
# [22]	validation_0-rmse:54.80997	validation_1-rmse:62.48698
# [23]	validation_0-rmse:49.49541	validation_1-rmse:57.97093
# [24]	validation_0-rmse:44.68273	validation_1-rmse:54.13522
# [25]	validation_0-rmse:40.34185	validation_1-rmse:50.62964
# [26]	validation_0-rmse:36.42369	validation_1-rmse:47.70953
# [27]	validation_0-rmse:32.89011	validation_1-rmse:45.20421
# [28]	validation_0-rmse:29.70891	validation_1-rmse:42.50986
# [29]	validation_0-rmse:26.82481	validation_1-rmse:40.42888
# [30]	validation_0-rmse:24.22912	validation_1-rmse:38.47582
# [31]	validation_0-rmse:21.88150	validation_1-rmse:36.88299
# [32]	validation_0-rmse:19.76324	validation_1-rmse:35.59944
# [33]	validation_0-rmse:17.85287	validation_1-rmse:34.49401
# [34]	validation_0-rmse:16.12930	validation_1-rmse:33.44432
# [35]	validation_0-rmse:14.57475	validation_1-rmse:32.62185
# [36]	validation_0-rmse:13.17093	validation_1-rmse:31.86928
# [37]	validation_0-rmse:11.90358	validation_1-rmse:31.23060
# [38]	validation_0-rmse:10.76194	validation_1-rmse:30.71316
# [39]	validation_0-rmse:9.72953	validation_1-rmse:30.14698
# [40]	validation_0-rmse:8.79685	validation_1-rmse:29.72859
# [41]	validation_0-rmse:7.95655	validation_1-rmse:29.41438
# [42]	validation_0-rmse:7.19754	validation_1-rmse:29.09467
# [43]	validation_0-rmse:6.51367	validation_1-rmse:28.69917
# [44]	validation_0-rmse:5.89687	validation_1-rmse:28.43902
# [45]	validation_0-rmse:5.33963	validation_1-rmse:28.21680
# [46]	validation_0-rmse:4.83605	validation_1-rmse:27.98475
# [47]	validation_0-rmse:4.38256	validation_1-rmse:27.87764
# [48]	validation_0-rmse:3.97414	validation_1-rmse:27.74273
# [49]	validation_0-rmse:3.60416	validation_1-rmse:27.62818
# [50]	validation_0-rmse:3.26925	validation_1-rmse:27.53294
# [51]	validation_0-rmse:2.96906	validation_1-rmse:27.42806
# [52]	validation_0-rmse:2.69947	validation_1-rmse:27.32207
# [53]	validation_0-rmse:2.45632	validation_1-rmse:27.23057
# [54]	validation_0-rmse:2.23625	validation_1-rmse:27.16659
# [55]	validation_0-rmse:2.03847	validation_1-rmse:27.10063
# [56]	validation_0-rmse:1.85891	validation_1-rmse:27.03891
# [57]	validation_0-rmse:1.69786	validation_1-rmse:26.98708
# [58]	validation_0-rmse:1.55503	validation_1-rmse:26.92070
# [59]	validation_0-rmse:1.42505	validation_1-rmse:26.87482
# [60]	validation_0-rmse:1.30751	validation_1-rmse:26.84854
# [61]	validation_0-rmse:1.20279	validation_1-rmse:26.82118
# [62]	validation_0-rmse:1.10826	validation_1-rmse:26.77850
# [63]	validation_0-rmse:1.02224	validation_1-rmse:26.74277
# [64]	validation_0-rmse:0.94499	validation_1-rmse:26.70724
# [65]	validation_0-rmse:0.87363	validation_1-rmse:26.67971
# [66]	validation_0-rmse:0.80718	validation_1-rmse:26.64885
# [67]	validation_0-rmse:0.74783	validation_1-rmse:26.61836
# [68]	validation_0-rmse:0.69450	validation_1-rmse:26.59083
# [69]	validation_0-rmse:0.64944	validation_1-rmse:26.56577
# [70]	validation_0-rmse:0.60595	validation_1-rmse:26.54942
# [71]	validation_0-rmse:0.56769	validation_1-rmse:26.52918
# [72]	validation_0-rmse:0.53234	validation_1-rmse:26.51474
# [73]	validation_0-rmse:0.50157	validation_1-rmse:26.49887
# [74]	validation_0-rmse:0.47570	validation_1-rmse:26.48472
# [75]	validation_0-rmse:0.44764	validation_1-rmse:26.47132
# [76]	validation_0-rmse:0.42050	validation_1-rmse:26.46667
# [77]	validation_0-rmse:0.39544	validation_1-rmse:26.45705
# [78]	validation_0-rmse:0.37327	validation_1-rmse:26.44818
# [79]	validation_0-rmse:0.35345	validation_1-rmse:26.44176
# [80]	validation_0-rmse:0.33312	validation_1-rmse:26.43971
# [81]	validation_0-rmse:0.31576	validation_1-rmse:26.43577
# [82]	validation_0-rmse:0.29841	validation_1-rmse:26.43358
# [83]	validation_0-rmse:0.28614	validation_1-rmse:26.43012
# [84]	validation_0-rmse:0.27616	validation_1-rmse:26.42685
# [85]	validation_0-rmse:0.26319	validation_1-rmse:26.42510
# [86]	validation_0-rmse:0.25503	validation_1-rmse:26.42140
# [87]	validation_0-rmse:0.24533	validation_1-rmse:26.41864
# [88]	validation_0-rmse:0.23650	validation_1-rmse:26.41575
# [89]	validation_0-rmse:0.23026	validation_1-rmse:26.41320
# [90]	validation_0-rmse:0.22402	validation_1-rmse:26.41100
# [91]	validation_0-rmse:0.21509	validation_1-rmse:26.40619
# [92]	validation_0-rmse:0.20677	validation_1-rmse:26.40241
# [93]	validation_0-rmse:0.20141	validation_1-rmse:26.39997
# [94]	validation_0-rmse:0.19562	validation_1-rmse:26.39483
# [95]	validation_0-rmse:0.18933	validation_1-rmse:26.38958
# [96]	validation_0-rmse:0.18414	validation_1-rmse:26.38726
# [97]	validation_0-rmse:0.17895	validation_1-rmse:26.38491
# [98]	validation_0-rmse:0.17303	validation_1-rmse:26.38229
# [99]	validation_0-rmse:0.16986	validation_1-rmse:26.38095
# [100]	validation_0-rmse:0.16458	validation_1-rmse:26.37960
# [101]	validation_0-rmse:0.16000	validation_1-rmse:26.38033
# [102]	validation_0-rmse:0.15466	validation_1-rmse:26.37991
# [103]	validation_0-rmse:0.15126	validation_1-rmse:26.38116
# [104]	validation_0-rmse:0.14853	validation_1-rmse:26.38072
# [105]	validation_0-rmse:0.14624	validation_1-rmse:26.38069
# [106]	validation_0-rmse:0.14337	validation_1-rmse:26.38129
# [107]	validation_0-rmse:0.13830	validation_1-rmse:26.38126
# [108]	validation_0-rmse:0.13654	validation_1-rmse:26.38125
# [109]	validation_0-rmse:0.13243	validation_1-rmse:26.37973
# [110]	validation_0-rmse:0.12852	validation_1-rmse:26.37857
# [111]	validation_0-rmse:0.12494	validation_1-rmse:26.37828
# [112]	validation_0-rmse:0.12284	validation_1-rmse:26.37748
# [113]	validation_0-rmse:0.11946	validation_1-rmse:26.37552
# [114]	validation_0-rmse:0.11765	validation_1-rmse:26.37600
# [115]	validation_0-rmse:0.11500	validation_1-rmse:26.37689
# [116]	validation_0-rmse:0.11271	validation_1-rmse:26.37697
# [117]	validation_0-rmse:0.11137	validation_1-rmse:26.37788
# [118]	validation_0-rmse:0.11018	validation_1-rmse:26.37760
# [119]	validation_0-rmse:0.10835	validation_1-rmse:26.38013
# [120]	validation_0-rmse:0.10651	validation_1-rmse:26.38020
# [121]	validation_0-rmse:0.10395	validation_1-rmse:26.38021
# [122]	validation_0-rmse:0.10237	validation_1-rmse:26.38050
# [123]	validation_0-rmse:0.10102	validation_1-rmse:26.38043
# [124]	validation_0-rmse:0.09985	validation_1-rmse:26.38086
# [125]	validation_0-rmse:0.09886	validation_1-rmse:26.38084
# [126]	validation_0-rmse:0.09707	validation_1-rmse:26.38031
# [127]	validation_0-rmse:0.09526	validation_1-rmse:26.37985
# [128]	validation_0-rmse:0.09132	validation_1-rmse:26.37866
# [129]	validation_0-rmse:0.08989	validation_1-rmse:26.37909
# [130]	validation_0-rmse:0.08690	validation_1-rmse:26.37795
# [131]	validation_0-rmse:0.08561	validation_1-rmse:26.37800
# [132]	validation_0-rmse:0.08335	validation_1-rmse:26.37699
# [133]	validation_0-rmse:0.08086	validation_1-rmse:26.37695
# [134]	validation_0-rmse:0.07976	validation_1-rmse:26.37731
# [135]	validation_0-rmse:0.07763	validation_1-rmse:26.37791
# [136]	validation_0-rmse:0.07694	validation_1-rmse:26.37693
# [137]	validation_0-rmse:0.07593	validation_1-rmse:26.37696
# [138]	validation_0-rmse:0.07486	validation_1-rmse:26.37683
# [139]	validation_0-rmse:0.07426	validation_1-rmse:26.37600
# [140]	validation_0-rmse:0.07211	validation_1-rmse:26.37593
# [141]	validation_0-rmse:0.07111	validation_1-rmse:26.37520
# [142]	validation_0-rmse:0.06912	validation_1-rmse:26.37492
# [143]	validation_0-rmse:0.06862	validation_1-rmse:26.37522
# [144]	validation_0-rmse:0.06717	validation_1-rmse:26.37493
# [145]	validation_0-rmse:0.06668	validation_1-rmse:26.37522
# [146]	validation_0-rmse:0.06489	validation_1-rmse:26.37431
# [147]	validation_0-rmse:0.06308	validation_1-rmse:26.37422
# [148]	validation_0-rmse:0.06203	validation_1-rmse:26.37450
# [149]	validation_0-rmse:0.06144	validation_1-rmse:26.37451
# [150]	validation_0-rmse:0.06102	validation_1-rmse:26.37471
# [151]	validation_0-rmse:0.05827	validation_1-rmse:26.37407
# [152]	validation_0-rmse:0.05570	validation_1-rmse:26.37309
# [153]	validation_0-rmse:0.05454	validation_1-rmse:26.37316
# [154]	validation_0-rmse:0.05392	validation_1-rmse:26.37273
# [155]	validation_0-rmse:0.05256	validation_1-rmse:26.37248
# [156]	validation_0-rmse:0.05207	validation_1-rmse:26.37204
# [157]	validation_0-rmse:0.05112	validation_1-rmse:26.37248
# [158]	validation_0-rmse:0.05060	validation_1-rmse:26.37260
# [159]	validation_0-rmse:0.05011	validation_1-rmse:26.37206
# [160]	validation_0-rmse:0.04979	validation_1-rmse:26.37224
# [161]	validation_0-rmse:0.04871	validation_1-rmse:26.37214
# [162]	validation_0-rmse:0.04840	validation_1-rmse:26.37230
# [163]	validation_0-rmse:0.04790	validation_1-rmse:26.37235
# [164]	validation_0-rmse:0.04703	validation_1-rmse:26.37223
# [165]	validation_0-rmse:0.04661	validation_1-rmse:26.37217
# [166]	validation_0-rmse:0.04623	validation_1-rmse:26.37222
# [167]	validation_0-rmse:0.04516	validation_1-rmse:26.37222
# [168]	validation_0-rmse:0.04426	validation_1-rmse:26.37219
# [169]	validation_0-rmse:0.04358	validation_1-rmse:26.37221
# [170]	validation_0-rmse:0.04276	validation_1-rmse:26.37160
# [171]	validation_0-rmse:0.04223	validation_1-rmse:26.37151
# [172]	validation_0-rmse:0.04197	validation_1-rmse:26.37151
# [173]	validation_0-rmse:0.04118	validation_1-rmse:26.37135
# [174]	validation_0-rmse:0.04037	validation_1-rmse:26.37092
# [175]	validation_0-rmse:0.04012	validation_1-rmse:26.37095
# [176]	validation_0-rmse:0.03957	validation_1-rmse:26.37060
# [177]	validation_0-rmse:0.03880	validation_1-rmse:26.36998
# [178]	validation_0-rmse:0.03820	validation_1-rmse:26.37008
# [179]	validation_0-rmse:0.03766	validation_1-rmse:26.37023
# [180]	validation_0-rmse:0.03747	validation_1-rmse:26.37023
# [181]	validation_0-rmse:0.03694	validation_1-rmse:26.36998
# [182]	validation_0-rmse:0.03672	validation_1-rmse:26.36997
# [183]	validation_0-rmse:0.03549	validation_1-rmse:26.36984
# [184]	validation_0-rmse:0.03467	validation_1-rmse:26.36966
# [185]	validation_0-rmse:0.03425	validation_1-rmse:26.36988
# [186]	validation_0-rmse:0.03386	validation_1-rmse:26.36951
# [187]	validation_0-rmse:0.03346	validation_1-rmse:26.36945
# [188]	validation_0-rmse:0.03300	validation_1-rmse:26.36967
# [189]	validation_0-rmse:0.03264	validation_1-rmse:26.36944
# [190]	validation_0-rmse:0.03218	validation_1-rmse:26.36940
# [191]	validation_0-rmse:0.03193	validation_1-rmse:26.36951
# [192]	validation_0-rmse:0.03119	validation_1-rmse:26.36933
# [193]	validation_0-rmse:0.03097	validation_1-rmse:26.36908
# [194]	validation_0-rmse:0.03016	validation_1-rmse:26.36877
# [195]	validation_0-rmse:0.02924	validation_1-rmse:26.36890
# [196]	validation_0-rmse:0.02889	validation_1-rmse:26.36864
# [197]	validation_0-rmse:0.02814	validation_1-rmse:26.36898
# [198]	validation_0-rmse:0.02782	validation_1-rmse:26.36870
# [199]	validation_0-rmse:0.02743	validation_1-rmse:26.36862
# [200]	validation_0-rmse:0.02701	validation_1-rmse:26.36837
# [201]	validation_0-rmse:0.02669	validation_1-rmse:26.36844
# [202]	validation_0-rmse:0.02551	validation_1-rmse:26.36860
# [203]	validation_0-rmse:0.02503	validation_1-rmse:26.36873
# [204]	validation_0-rmse:0.02457	validation_1-rmse:26.36849
# [205]	validation_0-rmse:0.02416	validation_1-rmse:26.36860
# [206]	validation_0-rmse:0.02327	validation_1-rmse:26.36870
# [207]	validation_0-rmse:0.02285	validation_1-rmse:26.36845
# [208]	validation_0-rmse:0.02221	validation_1-rmse:26.36830
# [209]	validation_0-rmse:0.02189	validation_1-rmse:26.36813
# [210]	validation_0-rmse:0.02142	validation_1-rmse:26.36836
# [211]	validation_0-rmse:0.02111	validation_1-rmse:26.36834
# [212]	validation_0-rmse:0.02082	validation_1-rmse:26.36817
# [213]	validation_0-rmse:0.02064	validation_1-rmse:26.36799
# [214]	validation_0-rmse:0.02028	validation_1-rmse:26.36793
# [215]	validation_0-rmse:0.02006	validation_1-rmse:26.36812
# [216]	validation_0-rmse:0.01991	validation_1-rmse:26.36823
# [217]	validation_0-rmse:0.01975	validation_1-rmse:26.36805
# [218]	validation_0-rmse:0.01945	validation_1-rmse:26.36822
# [219]	validation_0-rmse:0.01931	validation_1-rmse:26.36805
# [220]	validation_0-rmse:0.01908	validation_1-rmse:26.36777
# [221]	validation_0-rmse:0.01889	validation_1-rmse:26.36756
# [222]	validation_0-rmse:0.01869	validation_1-rmse:26.36739
# [223]	validation_0-rmse:0.01845	validation_1-rmse:26.36727
# [224]	validation_0-rmse:0.01821	validation_1-rmse:26.36707
# [225]	validation_0-rmse:0.01801	validation_1-rmse:26.36706
# [226]	validation_0-rmse:0.01742	validation_1-rmse:26.36686
# [227]	validation_0-rmse:0.01710	validation_1-rmse:26.36667
# [228]	validation_0-rmse:0.01692	validation_1-rmse:26.36633
# [229]	validation_0-rmse:0.01651	validation_1-rmse:26.36637
# [230]	validation_0-rmse:0.01593	validation_1-rmse:26.36635
# [231]	validation_0-rmse:0.01561	validation_1-rmse:26.36632
# [232]	validation_0-rmse:0.01512	validation_1-rmse:26.36605
# [233]	validation_0-rmse:0.01455	validation_1-rmse:26.36648
# [234]	validation_0-rmse:0.01431	validation_1-rmse:26.36639
# [235]	validation_0-rmse:0.01414	validation_1-rmse:26.36622
# [236]	validation_0-rmse:0.01390	validation_1-rmse:26.36609
# [237]	validation_0-rmse:0.01342	validation_1-rmse:26.36640
# [238]	validation_0-rmse:0.01314	validation_1-rmse:26.36638
# [239]	validation_0-rmse:0.01275	validation_1-rmse:26.36644
# [240]	validation_0-rmse:0.01264	validation_1-rmse:26.36651
# [241]	validation_0-rmse:0.01220	validation_1-rmse:26.36641
# [242]	validation_0-rmse:0.01199	validation_1-rmse:26.36649
# [243]	validation_0-rmse:0.01183	validation_1-rmse:26.36651
# [244]	validation_0-rmse:0.01163	validation_1-rmse:26.36651
# [245]	validation_0-rmse:0.01154	validation_1-rmse:26.36648
# [246]	validation_0-rmse:0.01129	validation_1-rmse:26.36651
# [247]	validation_0-rmse:0.01109	validation_1-rmse:26.36655
# [248]	validation_0-rmse:0.01089	validation_1-rmse:26.36660
# [249]	validation_0-rmse:0.01083	validation_1-rmse:26.36649
# [250]	validation_0-rmse:0.01065	validation_1-rmse:26.36636
# [251]	validation_0-rmse:0.01046	validation_1-rmse:26.36629
# [252]	validation_0-rmse:0.01033	validation_1-rmse:26.36629
# [253]	validation_0-rmse:0.01000	validation_1-rmse:26.36617
# [254]	validation_0-rmse:0.00993	validation_1-rmse:26.36614
# [255]	validation_0-rmse:0.00976	validation_1-rmse:26.36608
# [256]	validation_0-rmse:0.00951	validation_1-rmse:26.36610
# [257]	validation_0-rmse:0.00933	validation_1-rmse:26.36611
# [258]	validation_0-rmse:0.00926	validation_1-rmse:26.36608
# [259]	validation_0-rmse:0.00897	validation_1-rmse:26.36610
# [260]	validation_0-rmse:0.00880	validation_1-rmse:26.36602
# [261]	validation_0-rmse:0.00856	validation_1-rmse:26.36606
# [262]	validation_0-rmse:0.00843	validation_1-rmse:26.36606
# [263]	validation_0-rmse:0.00818	validation_1-rmse:26.36606
# [264]	validation_0-rmse:0.00804	validation_1-rmse:26.36603
# [265]	validation_0-rmse:0.00793	validation_1-rmse:26.36598
# [266]	validation_0-rmse:0.00783	validation_1-rmse:26.36601
# [267]	validation_0-rmse:0.00780	validation_1-rmse:26.36593
# [268]	validation_0-rmse:0.00764	validation_1-rmse:26.36588
# [269]	validation_0-rmse:0.00751	validation_1-rmse:26.36595
# [270]	validation_0-rmse:0.00742	validation_1-rmse:26.36598
# [271]	validation_0-rmse:0.00721	validation_1-rmse:26.36595
# [272]	validation_0-rmse:0.00711	validation_1-rmse:26.36597
# [273]	validation_0-rmse:0.00698	validation_1-rmse:26.36596
# [274]	validation_0-rmse:0.00687	validation_1-rmse:26.36594
# [275]	validation_0-rmse:0.00684	validation_1-rmse:26.36587
# [276]	validation_0-rmse:0.00672	validation_1-rmse:26.36581
# [277]	validation_0-rmse:0.00661	validation_1-rmse:26.36575
# [278]	validation_0-rmse:0.00658	validation_1-rmse:26.36567
# [279]	validation_0-rmse:0.00652	validation_1-rmse:26.36566
# [280]	validation_0-rmse:0.00647	validation_1-rmse:26.36558
# [281]	validation_0-rmse:0.00641	validation_1-rmse:26.36558
# [282]	validation_0-rmse:0.00632	validation_1-rmse:26.36555
# [283]	validation_0-rmse:0.00630	validation_1-rmse:26.36550
# [284]	validation_0-rmse:0.00611	validation_1-rmse:26.36553
# [285]	validation_0-rmse:0.00605	validation_1-rmse:26.36550
# [286]	validation_0-rmse:0.00595	validation_1-rmse:26.36552
# [287]	validation_0-rmse:0.00593	validation_1-rmse:26.36546
# [288]	validation_0-rmse:0.00576	validation_1-rmse:26.36547
# [289]	validation_0-rmse:0.00561	validation_1-rmse:26.36546
# [290]	validation_0-rmse:0.00545	validation_1-rmse:26.36545
# [291]	validation_0-rmse:0.00541	validation_1-rmse:26.36541
# [292]	validation_0-rmse:0.00530	validation_1-rmse:26.36539
# [293]	validation_0-rmse:0.00516	validation_1-rmse:26.36533
# [294]	validation_0-rmse:0.00506	validation_1-rmse:26.36532
# [295]	validation_0-rmse:0.00501	validation_1-rmse:26.36533
# [296]	validation_0-rmse:0.00489	validation_1-rmse:26.36530
# [297]	validation_0-rmse:0.00481	validation_1-rmse:26.36530
# [298]	validation_0-rmse:0.00466	validation_1-rmse:26.36532
# [299]	validation_0-rmse:0.00455	validation_1-rmse:26.36534
# [300]	validation_0-rmse:0.00446	validation_1-rmse:26.36531
# [301]	validation_0-rmse:0.00441	validation_1-rmse:26.36531
# [302]	validation_0-rmse:0.00437	validation_1-rmse:26.36528
# [303]	validation_0-rmse:0.00434	validation_1-rmse:26.36524
# [304]	validation_0-rmse:0.00427	validation_1-rmse:26.36523
# [305]	validation_0-rmse:0.00422	validation_1-rmse:26.36524
# [306]	validation_0-rmse:0.00416	validation_1-rmse:26.36522
# [307]	validation_0-rmse:0.00411	validation_1-rmse:26.36523
# [308]	validation_0-rmse:0.00404	validation_1-rmse:26.36523
# [309]	validation_0-rmse:0.00401	validation_1-rmse:26.36526
# [310]	validation_0-rmse:0.00398	validation_1-rmse:26.36525
# [311]	validation_0-rmse:0.00388	validation_1-rmse:26.36524
# [312]	validation_0-rmse:0.00384	validation_1-rmse:26.36524
# [313]	validation_0-rmse:0.00375	validation_1-rmse:26.36523
# [314]	validation_0-rmse:0.00370	validation_1-rmse:26.36522
# [315]	validation_0-rmse:0.00364	validation_1-rmse:26.36524
# [316]	validation_0-rmse:0.00361	validation_1-rmse:26.36524
# [317]	validation_0-rmse:0.00357	validation_1-rmse:26.36524
# [318]	validation_0-rmse:0.00355	validation_1-rmse:26.36523
# [319]	validation_0-rmse:0.00351	validation_1-rmse:26.36521
# [320]	validation_0-rmse:0.00343	validation_1-rmse:26.36519
# [321]	validation_0-rmse:0.00339	validation_1-rmse:26.36519
# [322]	validation_0-rmse:0.00337	validation_1-rmse:26.36518
# [323]	validation_0-rmse:0.00331	validation_1-rmse:26.36520
# [324]	validation_0-rmse:0.00326	validation_1-rmse:26.36520
# [325]	validation_0-rmse:0.00321	validation_1-rmse:26.36520
# [326]	validation_0-rmse:0.00316	validation_1-rmse:26.36520
# [327]	validation_0-rmse:0.00313	validation_1-rmse:26.36519
# [328]	validation_0-rmse:0.00308	validation_1-rmse:26.36518
# [329]	validation_0-rmse:0.00303	validation_1-rmse:26.36518
# [330]	validation_0-rmse:0.00297	validation_1-rmse:26.36521
# [331]	validation_0-rmse:0.00294	validation_1-rmse:26.36519
# [332]	validation_0-rmse:0.00292	validation_1-rmse:26.36519
# [333]	validation_0-rmse:0.00289	validation_1-rmse:26.36519
# [334]	validation_0-rmse:0.00285	validation_1-rmse:26.36516
# [335]	validation_0-rmse:0.00277	validation_1-rmse:26.36513
# [336]	validation_0-rmse:0.00273	validation_1-rmse:26.36508
# [337]	validation_0-rmse:0.00270	validation_1-rmse:26.36508
# [338]	validation_0-rmse:0.00269	validation_1-rmse:26.36507
# [339]	validation_0-rmse:0.00263	validation_1-rmse:26.36506
# [340]	validation_0-rmse:0.00260	validation_1-rmse:26.36505
# [341]	validation_0-rmse:0.00256	validation_1-rmse:26.36505
# [342]	validation_0-rmse:0.00253	validation_1-rmse:26.36506
# [343]	validation_0-rmse:0.00252	validation_1-rmse:26.36506
# [344]	validation_0-rmse:0.00248	validation_1-rmse:26.36506
# [345]	validation_0-rmse:0.00246	validation_1-rmse:26.36506
# [346]	validation_0-rmse:0.00240	validation_1-rmse:26.36506
# [347]	validation_0-rmse:0.00237	validation_1-rmse:26.36505
# [348]	validation_0-rmse:0.00232	validation_1-rmse:26.36503
# [349]	validation_0-rmse:0.00229	validation_1-rmse:26.36501
# [350]	validation_0-rmse:0.00227	validation_1-rmse:26.36501
# [351]	validation_0-rmse:0.00222	validation_1-rmse:26.36501
# [352]	validation_0-rmse:0.00218	validation_1-rmse:26.36499
# [353]	validation_0-rmse:0.00214	validation_1-rmse:26.36500
# [354]	validation_0-rmse:0.00211	validation_1-rmse:26.36498
# [355]	validation_0-rmse:0.00207	validation_1-rmse:26.36498
# [356]	validation_0-rmse:0.00204	validation_1-rmse:26.36498
# [357]	validation_0-rmse:0.00201	validation_1-rmse:26.36498
# [358]	validation_0-rmse:0.00198	validation_1-rmse:26.36498
# [359]	validation_0-rmse:0.00194	validation_1-rmse:26.36496
# [360]	validation_0-rmse:0.00189	validation_1-rmse:26.36496
# [361]	validation_0-rmse:0.00185	validation_1-rmse:26.36498
# [362]	validation_0-rmse:0.00181	validation_1-rmse:26.36498
# [363]	validation_0-rmse:0.00178	validation_1-rmse:26.36498
# [364]	validation_0-rmse:0.00173	validation_1-rmse:26.36498
# [365]	validation_0-rmse:0.00168	validation_1-rmse:26.36497
# [366]	validation_0-rmse:0.00166	validation_1-rmse:26.36497
# [367]	validation_0-rmse:0.00163	validation_1-rmse:26.36496
# [368]	validation_0-rmse:0.00160	validation_1-rmse:26.36495
# [369]	validation_0-rmse:0.00157	validation_1-rmse:26.36493
# [370]	validation_0-rmse:0.00154	validation_1-rmse:26.36494
# [371]	validation_0-rmse:0.00151	validation_1-rmse:26.36492
# [372]	validation_0-rmse:0.00148	validation_1-rmse:26.36495
# [373]	validation_0-rmse:0.00145	validation_1-rmse:26.36494
# [374]	validation_0-rmse:0.00141	validation_1-rmse:26.36493
# [375]	validation_0-rmse:0.00140	validation_1-rmse:26.36494
# [376]	validation_0-rmse:0.00139	validation_1-rmse:26.36490
# [377]	validation_0-rmse:0.00138	validation_1-rmse:26.36491
# [378]	validation_0-rmse:0.00136	validation_1-rmse:26.36490
# [379]	validation_0-rmse:0.00134	validation_1-rmse:26.36489
# [380]	validation_0-rmse:0.00132	validation_1-rmse:26.36489
# [381]	validation_0-rmse:0.00129	validation_1-rmse:26.36489
# [382]	validation_0-rmse:0.00126	validation_1-rmse:26.36486
# [383]	validation_0-rmse:0.00125	validation_1-rmse:26.36486
# [384]	validation_0-rmse:0.00123	validation_1-rmse:26.36486
# [385]	validation_0-rmse:0.00119	validation_1-rmse:26.36486
# [386]	validation_0-rmse:0.00118	validation_1-rmse:26.36486
# [387]	validation_0-rmse:0.00116	validation_1-rmse:26.36486
# [388]	validation_0-rmse:0.00113	validation_1-rmse:26.36485
# [389]	validation_0-rmse:0.00111	validation_1-rmse:26.36484
# [390]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [391]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [392]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [393]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [394]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [395]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [396]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [397]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [398]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [399]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [400]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [401]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [402]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [403]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [404]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [405]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [406]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [407]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [408]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [409]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [410]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [411]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [412]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [413]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [414]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [415]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [416]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [417]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [418]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [419]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [420]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [421]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [422]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [423]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [424]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [425]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [426]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [427]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [428]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [429]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [430]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [431]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [432]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [433]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [434]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [435]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [436]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [437]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [438]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# [439]	validation_0-rmse:0.00110	validation_1-rmse:26.36485
# XGBoost RMSE: 695.1048323711562
# XGBoost R2 Score: 0.9974480481878784

# %%
feature_importances = xgb_model.feature_importances_

# Map feature importances to feature names
feature_importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#                      Feature    Importance
# 6        shareholdersEquity_  9.853559e-01
# 0                     ticker  1.444983e-02
# 7               totalAssets_  7.211386e-05
# 5           operatingIncome_  6.163237e-05
# 1   commonSharesOutstanding_  4.225534e-05
# 21                      m2SA  5.403246e-06
# 10         debtToTotalAssets  5.387793e-06
# 4                 netIncome_  9.489915e-07
# 23                m2Velocity  8.140358e-07
# 8                       EPS_  6.924125e-07
# 19                 salePrice  6.347980e-07
# 3        capitalExpenditure_  5.633736e-07
# 9           costOfGoodsSold_  5.048854e-07
# 16              ebitdaGrowth  4.402974e-07
# 13             revenueGrowth  4.211877e-07
# 25               EBITDA_lag1  3.899926e-07
# 2        commonSharesTraded_  3.359559e-07
# 14           netIncomeGrowth  3.097017e-07
# 24                 primeRate  3.093878e-07
# 18                    EBITDA  2.820607e-07
# 22             m2m1GrowthGap  2.081360e-07
# 20                 realGDPSA  2.019953e-07
# 27                   quarter  1.852445e-07
# 15                       mva  1.762142e-07
# 11                 niToAsset  1.057749e-07
# 12                       ROA  6.091255e-08
# 17               companyName  2.920804e-09
# 26                      year  0.000000e+00

# %% [markdown]
# # Implement Random Forest model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Initialize and train the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate model performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 657.2626252497662
# R^2 Score: 0.9975869790146267

# %%
feature_importances = rf_model.feature_importances_

# Map feature importances to feature names
feature_importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#                      Feature  Importance
# 6        shareholdersEquity_    0.991392
# 7               totalAssets_    0.003779
# 0                     ticker    0.001472
# 17               companyName    0.001136
# 25               EBITDA_lag1    0.000558
# 9           costOfGoodsSold_    0.000504
# 10         debtToTotalAssets    0.000254
# 18                    EBITDA    0.000171
# 8                       EPS_    0.000154
# 21                      m2SA    0.000076
# 1   commonSharesOutstanding_    0.000064
# 20                 realGDPSA    0.000057
# 5           operatingIncome_    0.000044
# 15                       mva    0.000040
# 22             m2m1GrowthGap    0.000039
# 16              ebitdaGrowth    0.000031
# 3        capitalExpenditure_    0.000031
# 26                      year    0.000030
# 19                 salePrice    0.000029
# 12                       ROA    0.000023
# 23                m2Velocity    0.000021
# 14           netIncomeGrowth    0.000019
# 24                 primeRate    0.000017
# 11                 niToAsset    0.000016
# 2        commonSharesTraded_    0.000016
# 13             revenueGrowth    0.000010
# 4                 netIncome_    0.000009
# 27                   quarter    0.000008
